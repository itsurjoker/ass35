# %%
#Q1.

import numpy as np
from scipy.stats import f

def variance_ratio_test(data1, data2):
    # Calculate sample variances
    variance1 = np.var(data1, ddof=1)  # Using ddof=1 for sample variance
    variance2 = np.var(data2, ddof=1)
    
    # Determine larger and smaller variances
    larger_variance = max(variance1, variance2)
    smaller_variance = min(variance1, variance2)
    
    # Calculate F-value
    f_value = larger_variance / smaller_variance
    
    # Calculate degrees of freedom
    df1 = len(data1) - 1
    df2 = len(data2) - 1
    
    # Calculate p-value using F-distribution's CDF
    p_value = 1 - f.cdf(f_value, df1, df2)
    
    return f_value, p_value

# Example usage
data1 = np.array([12, 15, 18, 21, 24])
data2 = np.array([10, 14, 16, 20, 22])

f_value, p_value = variance_ratio_test(data1, data2)
print("F-value:", f_value)
print("p-value:", p_value)
# Out:
# F-value: 1.0133333333333332
# p-value: 0.4950331851949099

# %%
#Q2.

from scipy.stats import f

def critical_f_value(dfn, dfd, alpha):
    """
    Calculate the critical F-value for a two-tailed test.
    
    Parameters:
    dfn (int): Degrees of freedom for the numerator.
    dfd (int): Degrees of freedom for the denominator.
    alpha (float): Significance level.
    
    Returns:
    float: Critical F-value.
    """
    # Calculate the critical F-value for the lower tail
    lower_tail = f.ppf(alpha / 2, dfn, dfd)
    
    # Calculate the critical F-value for the upper tail
    upper_tail = f.ppf(1 - alpha / 2, dfn, dfd)
    
    # Return the average of the two critical values for the two-tailed test
    return (lower_tail + upper_tail) / 2

# Example usage
degrees_of_freedom_numerator = 5
degrees_of_freedom_denominator = 10
significance_level = 0.05

critical_f = critical_f_value(degrees_of_freedom_numerator, degrees_of_freedom_denominator, significance_level)
print(f"Critical F-value: {critical_f}")
# Out:
# Critical F-value: 2.193581184609308

# %%
#Q3.

import numpy as np
from scipy.stats import f

# Set the random seed for reproducibility
np.random.seed(42)

# Parameters for the normal distributions
mean1 = 0
stddev1 = 2
sample_size1 = 50

mean2 = 0
stddev2 = 3
sample_size2 = 60

# Generate random samples from the two normal distributions
sample1 = np.random.normal(mean1, stddev1, sample_size1)
sample2 = np.random.normal(mean2, stddev2, sample_size2)

# Perform F-test
f_value = np.var(sample1, ddof=1) / np.var(sample2, ddof=1)
df1 = sample_size1 - 1
df2 = sample_size2 - 1
p_value = f.sf(f_value, df1, df2)

# Output the results
print("F-value:", f_value)
print("Degrees of Freedom:", df1, ",", df2)
print("p-value:", p_value)
# Out:
# F-value: 0.5164495614370478
# Degrees of Freedom: 49 , 59
# p-value: 0.9906940506640605

# %% [raw]
# #Q4.
#
#
# To conduct an F-test to determine if the variances of two populations are significantly different, you can follow these steps:
#
# Step 1: State the hypotheses:
#
#     Null Hypothesis (H0): The variances of the two populations are equal.
#     Alternative Hypothesis (Ha): The variances of the two populations are not equal.
#
# Step 2: Determine the significance level (α):
# You're given that the significance level is 5%, which corresponds to α = 0.05.
#
# Step 3: Calculate the test statistic:
# The F-test statistic can be calculated using the formula:
#
# F=s12/s22
#
# Where:
#
#     s12s12​ = Sample variance of the first population (known variance = 10)
#     s22s22​ = Sample variance of the second population (known variance = 15)
#
# In this case, since you have the known population variances, you can use these values directly. However, note that the F-test is usually applied when you have sample variances and not population variances.
#
# Substitute the values:
# F=10/15=0.6667
#
# Step 4: Determine the critical value:
# The critical value for an F-test with 11 degrees of freedom for the numerator and 11 degrees of freedom for the denominator (both sample sizes are 12) at a significance level of 0.05 can be found using statistical tables or calculators. For α = 0.05 and degrees of freedom 11 and 11, the critical value is approximately 2.96.
#
# Step 5: Compare the test statistic and critical value:
# Compare the calculated F-test statistic (0.6667) with the critical value (2.96). If the calculated F-test statistic is greater than the critical value, you would reject the null hypothesis. If it's less than or equal to the critical value, you would fail to reject the null hypothesis.
#
# In this case, 0.6667 < 2.96, so you would fail to reject the null hypothesis.
#
# Step 6: Make a decision:
# Since you failed to reject the null hypothesis, you do not have enough evidence to conclude that the variances of the two populations are significantly different at the 5% significance level.
#
# Keep in mind that the F-test is sensitive to the assumption of normality and independence in the populations. Also, this analysis assumes that you're working with unbiased sample variances and that the populations are approximately normally distributed.

# %% [raw]
# #Q5.
#
# To conduct an F-test for comparing variances, you can use the following steps:
#
# Step 1: Set up hypotheses
#
#     Null Hypothesis (H0): The population variance is equal to the claimed variance (σ² = 0.005).
#     Alternative Hypothesis (Ha): The population variance is not equal to the claimed variance (σ² ≠ 0.005).
#
# Step 2: Determine the significance level
#
# Given that the significance level is 1%, this means α = 0.01.
#
# Step 3: Calculate the F-statistic
#
# The F-statistic is calculated as the ratio of the sample variances:
#
# F = Sample Variance 1 / Sample Variance 2
#
# Where:
#
#     Sample Variance 1 = Sample variance of the larger sample (0.006 in this case)
#     Sample Variance 2 = Claimed population variance (0.005)
#
# Substitute the values:
# F = 0.006 / 0.005 = 1.2
#
# Step 4: Determine the critical value
#
# Since we're conducting a two-tailed test, we need to find the critical F-values from an F-distribution table or calculator. The degrees of freedom for the numerator and denominator are (n1 - 1) and (n2 - 1) respectively, where n1 is the sample size of the larger variance (25 in this case) and n2 is 1 (since you're comparing it to a single value, the claimed variance).
#
# For a significance level of 1% and degrees of freedom (24, 1), the critical F-values are approximately 32.85 and 1/32.85 = 0.0304.
#
# Step 5: Compare the calculated F-statistic with the critical value
#
# Since the calculated F-statistic (1.2) is smaller than the critical value of 32.85, we fail to reject the null hypothesis.
#
# Step 6: Make a decision
#
# Since we failed to reject the null hypothesis, we do not have enough evidence to say that the population variance is significantly different from the claimed variance. In other words, at the 1% significance level, the data does not provide enough evidence to conclude that the manufacturer's claim is unjustified.
#
# Keep in mind that failing to reject the null hypothesis doesn't prove the claim is justified; it simply means you don't have enough evidence to dispute it based on the given sample.

# %%
#Q6.


def f_distribution_mean_variance(df_num, df_den):
    if df_num <= 0 or df_den <= 0:
        raise ValueError("Degrees of freedom must be greater than 0")
    
    if df_den <= 2:
        raise ValueError("Degrees of freedom for the denominator must be greater than 2")
    
    mean = df_den / (df_den - 2)
    variance = (2 * (df_den ** 2) * (df_num + df_den - 2)) / (df_num * (df_den - 2) ** 2 * (df_den - 4))
    
    return mean, variance

df_num = 5
df_den = 10
mean, variance = f_distribution_mean_variance(df_num, df_den)
print("Mean:", mean)
print("Variance:", variance)
# Out:
# Mean: 1.25
# Variance: 1.3541666666666667

# %% [raw]
# #Q7.
#
#
# To conduct an F-test to determine if the variances of two populations are significantly different, we can use the F-statistic formula:
#
# F=S12/S22
#
# where S12S12​ is the larger sample variance and S22S22​ is the smaller sample variance. In this case, we'll use S12=25S12​=25 and S22=20S22​=20. The null hypothesis (H0H0​) is that the variances are equal, and the alternative hypothesis (H1H1​) is that the variances are significantly different.
#
# The critical value of the F-distribution at the 10% significance level for the given degrees of freedom can be looked up from an F-table or calculated using statistical software.
#
# Let's perform the calculations step by step:
#
#     Calculate the F-statistic:
#     F=S12/S22=25/20=1.25
#
#     Determine the degrees of freedom for each sample:
#     For the first sample (10 measurements), degrees of freedom df1=n1−1=10−1=9df1​=n1​−1=10−1=9.
#     For the second sample (15 measurements), degrees of freedom df2=n2−1=15−1=14df2​=n2​−1=15−1=14.
#
#     Look up or calculate the critical value of the F-distribution with df1=9df1​=9 and df2=14df2​=14 at the 10% significance level. Let's say this value is FcritFcrit​.
#
#     Compare the calculated F-statistic with the critical value:
#         If F>FcritF>Fcrit​, reject the null hypothesis and conclude that the variances are significantly different.
#         If F≤FcritF≤Fcrit​, fail to reject the null hypothesis and conclude that there is not enough evidence to suggest significant differences in variances.
#
# Please note that the specific critical value FcritFcrit​ will depend on the degrees of freedom for the two samples and the chosen significance level. You'll need to use a statistical table or software to find this value. If you have access to statistical software (such as R or Python), you can also calculate the p-value associated with the F-statistic and use it to make a decision about the null hypothesis.

# %% [raw]
# #Q8.
#
#
# To conduct an F-test to determine if the variances of two samples are significantly different, you can follow these steps:
#
# Step 1: Define the null and alternative hypotheses:
#
#     Null Hypothesis (H0): The variances of the two populations are equal.
#     Alternative Hypothesis (Ha): The variances of the two populations are not equal.
#
# Step 2: Calculate the variances of the samples:
# Calculate the sample variances for each group.
#
# For Restaurant A:
#
#     Sample size (n1) = 7
#     Mean (x̄1) = (24 + 25 + 28 + 23 + 22 + 20 + 27) / 7 = 24.14
#     Sample variance (s1^2) = Σ(xi - x̄1)^2 / (n1 - 1)
#     = (1^2 + 1^2 + 4^2 + (-1.14)^2 + (-2.14)^2 + (-4.14)^2 + 2.86^2) / 6
#     ≈ 8.95
#
# For Restaurant B:
#
#     Sample size (n2) = 6
#     Mean (x̄2) = (31 + 33 + 35 + 30 + 32 + 36) / 6 = 32.83
#     Sample variance (s2^2) = Σ(xi - x̄2)^2 / (n2 - 1)
#     = ((-1.83)^2 + 0.17^2 + 2.17^2 + (-2.83)^2 + (-0.83)^2 + 3.17^2) / 5
#     ≈ 5.67
#
# Step 3: Calculate the F-statistic:
# The F-statistic is calculated as the ratio of the larger variance to the smaller variance.
#
# F = s1^2 / s2^2 ≈ 8.95 / 5.67 ≈ 1.578
#
# Step 4: Determine the critical F-value:
# The critical F-value depends on the significance level (α = 0.05) and the degrees of freedom for each sample (df1 = n1 - 1 and df2 = n2 - 1).
#
# Using an F-distribution table or calculator, with df1 = 6 and df2 = 5 at α = 0.05 significance level, the critical F-value is approximately 5.79.
#
# Step 5: Compare the calculated F-statistic with the critical F-value:
# Since the calculated F-statistic (1.578) is smaller than the critical F-value (5.79), we fail to reject the null hypothesis.
#
# Step 6: Make a conclusion:
# Based on the analysis, at the 5% significance level, we do not have enough evidence to conclude that the variances of the waiting times at the two restaurants are significantly different.

# %% [raw]
# #Q9.
#
#
# To conduct an F-test to determine if the variances of two groups are significantly different, you'll need to follow these steps:
#
#     Calculate the variances of both groups:
#
#     For Group A:
#     Mean (x̄_A) = (80 + 85 + 90 + 92 + 87 + 83) / 6 = 87.83
#     Variance (s^2_A) = Σ(xi - x̄_A)^2 / (n_A - 1) = (40.47 + 2.77 + 10.47 + 20.77 + 3.47 + 17.17) / 5 = 19.38
#
#     For Group B:
#     Mean (x̄_B) = (75 + 78 + 82 + 79 + 81 + 84) / 6 = 79.83
#     Variance (s^2_B) = Σ(xi - x̄_B)^2 / (n_B - 1) = (18.07 + 1.23 + 7.43 + 0.43 + 1.43 + 13.13) / 5 = 8.53
#
#     Calculate the F-statistic:
#
#     F = s^2_A / s^2_B = 19.38 / 8.53 ≈ 2.27
#
#     Find the critical F-value:
#
#     The critical F-value can be found using an F-distribution table or calculator, with degrees of freedom for both groups. The degrees of freedom for Group A is (n_A - 1) = 5 and for Group B is (n_B - 1) = 5.
#
#     At the 1% significance level and degrees of freedom (5, 5), the critical F-value is approximately 8.89.
#
#     Compare the calculated F-statistic to the critical F-value:
#
#     F (calculated) = 2.27
#     F (critical) = 8.89
#
# Since the calculated F-statistic (2.27) is less than the critical F-value (8.89), we do not have enough evidence to reject the null hypothesis. The null hypothesis in this case states that the variances of the two groups are not significantly different.
#
# In conclusion, at the 1% significance level, the data does not provide enough evidence to suggest that the variances of Group A and Group B are significantly different.
